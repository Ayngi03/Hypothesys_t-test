# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/kaggle/input/employee-dataset/Employee.csv')
df.head(10)
# Out:
#    Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0  Bachelors         2017  Bangalore            3   34    Male          No
# 1  Bachelors         2013       Pune            1   28  Female          No
# 2  Bachelors         2014  New Delhi            3   38  Female          No
# 3    Masters         2016  Bangalore            3   27    Male          No
# 4    Masters         2017       Pune            3   24    Male         Yes
# 5  Bachelors         2016  Bangalore            3   22    Male          No
# 6  Bachelors         2015  New Delhi            3   38    Male          No
# 7  Bachelors         2016  Bangalore            3   34  Female          No
# 8  Bachelors         2016       Pune            3   23    Male          No
# 9    Masters         2017  New Delhi            2   37    Male          No
#
#    ExperienceInCurrentDomain  LeaveOrNot
# 0                          0           0
# 1                          3           1
# ...

# %%
df.tail(5)
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
#       ExperienceInCurrentDomain  LeaveOrNot
# 4648                          4           0
# 4649                          2           1
# 4650                          5           1
# 4651                          2           0
# 4652                          4           0

# %%
print(df.isna().sum())
print(df.isnull().any())
# Out:
# Education                    0
# JoiningYear                  0
# City                         0
# PaymentTier                  0
# Age                          0
# Gender                       0
# EverBenched                  0
# ExperienceInCurrentDomain    0
# LeaveOrNot                   0
# dtype: int64
# Education                    False
# JoiningYear                  False
# City                         False
# PaymentTier                  False
# Age                          False
# Gender                       False
# EverBenched                  False
# ExperienceInCurrentDomain    False
# LeaveOrNot                   False
# dtype: bool

# %%
df.dtypes
# Out:
# Education                    object
# JoiningYear                   int64
# City                         object
# PaymentTier                   int64
# Age                           int64
# Gender                       object
# EverBenched                  object
# ExperienceInCurrentDomain     int64
# LeaveOrNot                    int64
# dtype: object

# %%
df.nunique()
df.duplicated().sum()
df.info()
df.describe()
df.count()
df.Education.nunique(),df.City.nunique(), df.Gender.nunique(),df.EverBenched.nunique()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4653 entries, 0 to 4652
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Education                  4653 non-null   object
#  1   JoiningYear                4653 non-null   int64
#  2   City                       4653 non-null   object
#  3   PaymentTier                4653 non-null   int64
#  4   Age                        4653 non-null   int64
#  5   Gender                     4653 non-null   object
#  6   EverBenched                4653 non-null   object
#  7   ExperienceInCurrentDomain  4653 non-null   int64
#  8   LeaveOrNot                 4653 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 327.3+ KB
#    Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0  Bachelors         2017  Bangalore            3   34    Male          No
# ...

# %% [markdown]
# **Hypothesys**

# %%
import numpy as np
from scipy import stats

N = 10
a = np.random.randn(N) + 2
b = np.random.randn(N)


var_a = a.var(ddof=1)
var_b = b.var(ddof=1)

#std deviation
s = np.sqrt((var_a + var_b)/2)
s

## Calculate the t-statistics
t = (a.mean() - b.mean())/(s*np.sqrt(2/N))

## Compare with the critical t-value
#Degrees of freedom
df = 2*N - 2
#p-value after comparison with the t 
p = 1 - stats.t.cdf(t,df=df)
print("t = " + str(t))
print("p = " + str(2*p))

## Cross Checking with the internal scipy function
t2, p2 = stats.ttest_ind(a,b)
print("t = " + str(t2))
print("p = " + str(p2))
# Out:
# t = 5.50068521646476
# p = 3.183143064000582e-05
# t = 5.50068521646476
# p = 3.1831430640127996e-05

# %%
Nx = 70
Ny = 40
x = np.random.randn(Nx) 
y = np.random.randn(Ny)+2
print("Nx: {}, Ny: {}".format(len(x), len(y)))
t3, p3 = stats.ttest_ind(y,x)
print("t = " + str(t3))
print("p = " + str(p3))
# Out:
# Nx: 70, Ny: 40
# t = 9.795627414888207
# p = 1.3605848720510364e-16

# %%
from scipy import stats
import pandas as pd

# %%
df=pd.read_csv('/kaggle/input/employee-dataset/Employee.csv')
df.head(10)
# Out:
#    Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0  Bachelors         2017  Bangalore            3   34    Male          No
# 1  Bachelors         2013       Pune            1   28  Female          No
# 2  Bachelors         2014  New Delhi            3   38  Female          No
# 3    Masters         2016  Bangalore            3   27    Male          No
# 4    Masters         2017       Pune            3   24    Male         Yes
# 5  Bachelors         2016  Bangalore            3   22    Male          No
# 6  Bachelors         2015  New Delhi            3   38    Male          No
# 7  Bachelors         2016  Bangalore            3   34  Female          No
# 8  Bachelors         2016       Pune            3   23    Male          No
# 9    Masters         2017  New Delhi            2   37    Male          No
#
#    ExperienceInCurrentDomain  LeaveOrNot
# 0                          0           0
# 1                          3           1
# ...

# %%
df.shape
# Out:
# (4653, 9)

# %%
df.isna().sum()
# Out:
# Education                    0
# JoiningYear                  0
# City                         0
# PaymentTier                  0
# Age                          0
# Gender                       0
# EverBenched                  0
# ExperienceInCurrentDomain    0
# LeaveOrNot                   0
# dtype: int64

# %%
df['Age'] = df['Age'].fillna(0)

# %%
# Divide dataset on Males and Females
# Find mean, median and mode of their Age
mean_heigth_by_Gender = df.groupby('Gender') ['Age'].mean()
median_Age = df.groupby('Gender')['Age'].median()
mode_Age = df.groupby('Gender')['Age'].apply(lambda x: x.mode().iloc[0])

print(f"Mean of Age : { mean_heigth_by_Gender}")
print(f"Mean of Age : {median_Age}")
print(f"Mean of Age : { mode_Age}")
# Out:
# Mean of Age : Gender
# Female    29.41600
# Male      29.37797
# Name: Age, dtype: float64
# Mean of Age : Gender
# Female    28.0
# Male      28.0
# Name: Age, dtype: float64
# Mean of Age : Gender
# Female    28
# Male      26
# Name: Age, dtype: int64

# %%
#Calculate T and P
male = df[df['Gender']=='Male']
female = df[df['Gender']=='Female']


t4, p4 = stats.ttest_ind(male['Age'],female['Age'])
print("t4 = " + str(t4))
print("p4 = " + str(p4))
# Out:
# t4 = -0.2636274828752633
# p4 = 0.7920786580734457

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
#Calculate T-crit
dffm = female.shape[0] + male.shape[0] -2
t_crit = stats.t.cdf(t4,df=dffm)
print ("t_crit = " + str(t_crit))
# Out:
# t_crit = 0.39603932903672284

# %% [markdown]
# **Linear_regression**

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('/kaggle/input/employee-dataset/Employee.csv')
df.head()
# Out:
#    Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0  Bachelors         2017  Bangalore            3   34    Male          No
# 1  Bachelors         2013       Pune            1   28  Female          No
# 2  Bachelors         2014  New Delhi            3   38  Female          No
# 3    Masters         2016  Bangalore            3   27    Male          No
# 4    Masters         2017       Pune            3   24    Male         Yes
#
#    ExperienceInCurrentDomain  LeaveOrNot
# 0                          0           0
# 1                          3           1
# 2                          2           0
# 3                          5           1
# 4                          2           1

# %%
df.describe()
# Out:
#        JoiningYear  PaymentTier          Age  ExperienceInCurrentDomain  \
# count  4653.000000  4653.000000  4653.000000                4653.000000
# mean   2015.062970     2.698259    29.393295                   2.905652
# std       1.863377     0.561435     4.826087                   1.558240
# min    2012.000000     1.000000    22.000000                   0.000000
# 25%    2013.000000     3.000000    26.000000                   2.000000
# 50%    2015.000000     3.000000    28.000000                   3.000000
# 75%    2017.000000     3.000000    32.000000                   4.000000
# max    2018.000000     3.000000    41.000000                   7.000000
#
#         LeaveOrNot
# count  4653.000000
# mean      0.343864
# std       0.475047
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
x = df.JoiningYear 
y = df.Education

# %%
plt.xlabel('JoiningYear')
plt.ylabel('Education')
plt.scatter(df.JoiningYear,df.Education,color='blue',marker='+')
